# %%
import numpy as np

# %%
aaa= np.random.randint(0,100,25)

# %%
bee = aaa.reshape([5,5])

# %%
bee[:,:] = 10

# %%
bee
# Out:
# array([[10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10]])

# %%
np.random.seed(101)
arr = np.random.randint(low=0,high=100,size=(5,5))

# %%
arr
# Out:
# array([[95, 11, 81, 70, 63],
#        [87, 75,  9, 77, 40],
#        [ 4, 63, 40, 60, 92],
#        [64,  5, 12, 93, 40],
#        [49, 83,  8, 29, 59]])

# %%
arr.max()
# Out:
# 95

# %%
arr.min()
# Out:
# 4

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('child.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=262x192 at 0x2954BE32390>

# %%
apic = np.asarray(pic)

# %%
apic.shape
# Out:
# (192, 262, 3)

# %%
type(apic)
# Out:
# numpy.ndarray

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
plt.imshow(apic)

# %%
mapic = apic.copy()

# %%
mapic[:,:,0] = 0
mapic[:,:,1] = 0

# %%
plt.imshow(mapic)

# %%
TEBRİKLER
# Out:
# -------------------------------------------------------------------------
# NameError                               Traceback (most recent call last)
# <ipython-input-115-b7def7c6cff1> in <module>
# ----> 1 TEBRİKLER
#
# NameError: name 'TEBRİKLER' is not defined
