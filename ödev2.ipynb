# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('child.jpg')

# %%
plt.imshow(child)

# %%
bgr_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(bgr_img)

# %%
bgr_img_copy = bgr_img.copy()

# %%
cv2.flip(bgr_img_copy,0)
# Out:
# array([[[ 52,  62,  51],
#         [ 55,  63,  52],
#         [ 56,  64,  53],
#         ...,
#         [ 29,  30,  25],
#         [ 26,  27,  22],
#         [ 24,  25,  20]],
#
#        [[ 55,  63,  52],
#         [ 55,  63,  52],
#         [ 56,  64,  53],
#         ...,
#         [ 29,  30,  25],
#         [ 27,  28,  23],
#         [ 25,  26,  21]],
#
#        [[ 56,  64,  53],
#         [ 57,  65,  54],
#         [ 58,  66,  55],
#         ...,
#         [ 30,  31,  26],
#         [ 28,  29,  24],
#         [ 26,  27,  22]],
#
#        ...,
#
#        [[127, 148,  79],
#         [127, 147,  84],
#         [125, 145,  92],
#         ...,
#         [ 31,  32,  24],
#         [ 29,  30,  22],
#         [ 28,  29,  21]],
#
#        [[124, 145,  78],
#         [123, 143,  82],
#         [121, 141,  90],
#         ...,
#         [ 30,  31,  23],
#         [ 28,  29,  21],
#         [ 26,  27,  19]],
#
#        [[121, 142,  75],
#         [120, 140,  79],
#         [119, 139,  88],
# ...

# %%
plt.imshow(cv2.flip(bgr_img_copy,0))

# %%
bgr_img_focused = cv2.rectangle(bgr_img,pt1=(99,12),pt2=(160,125),color=(255,0,0),thickness=5)

# %%
plt.imshow(bgr_img_focused)

# %%
img2 = cv2.imread('child.jpg')
img22 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
img222 = img22.copy()

# %%
plt.imshow(img22)

# %%
points = np.array([[90,125],[140,10],[160,125]])

# %%
cv2.polylines(img22,[points],isClosed=True,color=(0,0,255),thickness=5)
plt.imshow(img22)

# %%
cv2.fillPoly(img222,[points],color=(0,0,255))
plt.imshow(img222)

# %%
import cv2
import numpy as np

def daire_ciz(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(imgg,(x,y),10,color=(0,0,255),thickness=(20)) 
#
        
cv2.namedWindow('pink cicek')
cv2.setMouseCallback('pink cicek',daire_ciz)

#
imgg = cv2.imread('pink.jpg')

while True:
    cv2.imshow('pink cicek',imgg)
    
    if cv2.waitKey(20) & 0xFF == 27 :
        break

cv2.destroyAllWindows()
